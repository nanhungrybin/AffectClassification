# %%
from PIL import Image

# %%
Image.open('/workspace/CK plus/CK+48/anger/S010_004_00000017.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=48x48 at 0x7F54E9436F40>

# %%
Image.open('/workspace/ExpW/origin/afraid_African_214.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x320 at 0x7FE6F41A01C0>

# %%
import pandas as pd

# %%
train = pd.read_csv('/workspace/Affectnet/mapping_CK_annotation.csv')

# %%
train.head()
# Out:
#    Unnamed: 0                                               path  label
# 0           0  /workspace/CK plus/CK+48/anger/S010_004_000000...    0.0
# 1           1  /workspace/CK plus/CK+48/anger/S010_004_000000...    0.0
# 2           2  /workspace/CK plus/CK+48/anger/S010_004_000000...    0.0
# 3           3  /workspace/CK plus/CK+48/anger/S011_004_000000...    0.0
# 4           4  /workspace/CK plus/CK+48/anger/S011_004_000000...    0.0

# %%
train.label.value_counts()
# Out:
# 5.0    249
# 3.0    207
# 1.0    177
# 0.0    135
# 2.0     75
# 7.0     54
# Name: label, dtype: int64

# %%
tra = pd.read_csv('/workspace/Affectnet/CK_annotation.csv')

# %%
tra.label.value_counts()
# Out:
# surprise    249
# happy       207
# disgust     177
# anger       135
# sadness      84
# fear         75
# contempt     54
# Name: label, dtype: int64

# %%
label_mapping = {
    "anger": 0,
    "disgust": 1,
    "fear": 2,
    "happy": 3,
    "sadness": 4,
    "surprise": 5,
    "contempt": 6
}

tra['label'] = tra['label'].map(label_mapping)

tra.label.value_counts()
# Out:
# 5    249
# 3    207
# 1    177
# 0    135
# 4     84
# 2     75
# 6     54
# Name: label, dtype: int64

# %%
tra.to_csv("mapping_CK_annotation.csv")

# %%
exp = pd.read_csv("")
