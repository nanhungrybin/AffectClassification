# %%
import pandas as pd
df = pd.read_csv("/workspace/Affectnet/mapping_CK_annotation.csv")

# %%
df
# Out:
#      Unnamed: 0                                               path  label
# 0             0  D:\EXP_Data\CK plus\CK+48\anger\S010_004_00000...    0.0
# 1             1  D:\EXP_Data\CK plus\CK+48\anger\S010_004_00000...    0.0
# 2             2  D:\EXP_Data\CK plus\CK+48\anger\S010_004_00000...    0.0
# 3             3  D:\EXP_Data\CK plus\CK+48\anger\S011_004_00000...    0.0
# 4             4  D:\EXP_Data\CK plus\CK+48\anger\S011_004_00000...    0.0
# ..          ...                                                ...    ...
# 976         976  D:\EXP_Data\CK plus\CK+48\surprise\S137_001_00...    5.0
# 977         977  D:\EXP_Data\CK plus\CK+48\surprise\S137_001_00...    5.0
# 978         978  D:\EXP_Data\CK plus\CK+48\surprise\S138_004_00...    5.0
# 979         979  D:\EXP_Data\CK plus\CK+48\surprise\S138_004_00...    5.0
# 980         980  D:\EXP_Data\CK plus\CK+48\surprise\S138_004_00...    5.0
#
# [981 rows x 3 columns]

# %%
df["path"]
# Out:
# 0      D:\EXP_Data\CK plus\CK+48\anger\S010_004_00000...
# 1      D:\EXP_Data\CK plus\CK+48\anger\S010_004_00000...
# 2      D:\EXP_Data\CK plus\CK+48\anger\S010_004_00000...
# 3      D:\EXP_Data\CK plus\CK+48\anger\S011_004_00000...
# 4      D:\EXP_Data\CK plus\CK+48\anger\S011_004_00000...
#                              ...
# 976    D:\EXP_Data\CK plus\CK+48\surprise\S137_001_00...
# 977    D:\EXP_Data\CK plus\CK+48\surprise\S137_001_00...
# 978    D:\EXP_Data\CK plus\CK+48\surprise\S138_004_00...
# 979    D:\EXP_Data\CK plus\CK+48\surprise\S138_004_00...
# 980    D:\EXP_Data\CK plus\CK+48\surprise\S138_004_00...
# Name: path, Length: 981, dtype: object

# %%
import os

# "new_path" 열의 경로에서 역슬래시를 슬래시로 변경
df["path"] = df["path"].str.replace("\\", "/")

# 변경된 DataFrame 출력
print(df)
# Out:
#      Unnamed: 0                                               path  label
# 0             0  D:/EXP_Data/CK plus/CK+48/anger/S010_004_00000...    0.0
# 1             1  D:/EXP_Data/CK plus/CK+48/anger/S010_004_00000...    0.0
# 2             2  D:/EXP_Data/CK plus/CK+48/anger/S010_004_00000...    0.0
# 3             3  D:/EXP_Data/CK plus/CK+48/anger/S011_004_00000...    0.0
# 4             4  D:/EXP_Data/CK plus/CK+48/anger/S011_004_00000...    0.0
# ..          ...                                                ...    ...
# 976         976  D:/EXP_Data/CK plus/CK+48/surprise/S137_001_00...    5.0
# 977         977  D:/EXP_Data/CK plus/CK+48/surprise/S137_001_00...    5.0
# 978         978  D:/EXP_Data/CK plus/CK+48/surprise/S138_004_00...    5.0
# 979         979  D:/EXP_Data/CK plus/CK+48/surprise/S138_004_00...    5.0
# 980         980  D:/EXP_Data/CK plus/CK+48/surprise/S138_004_00...    5.0
#
# [981 rows x 3 columns]
# /tmp/ipykernel_60729/2591634340.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["path"] = df["path"].str.replace("\\", "/")

# %%
# 기준 경로 설정
base_path_current = "D:/EXP_Data"
base_path_new = "/workspace"

# "new_path" 열 추가
df["new_path"] = ""

# 각 행에 대해 경로 변경 수행
for index, row in df.iterrows():
    current_path = row["path"]
    
    # 기존 경로에서 기준 경로를 삭제하고, 새로운 경로로 변경
    relative_path = os.path.relpath(current_path, base_path_current)
    new_path = os.path.join(base_path_new, relative_path)
    
    # 변경된 경로를 DataFrame에 저장
    df.at[index, "new_path"] = new_path

# %%
df
# Out:
#                                               new_path  label
# 0    /workspace/CK plus/CK+48/anger/S010_004_000000...    0.0
# 1    /workspace/CK plus/CK+48/anger/S010_004_000000...    0.0
# 2    /workspace/CK plus/CK+48/anger/S010_004_000000...    0.0
# 3    /workspace/CK plus/CK+48/anger/S011_004_000000...    0.0
# 4    /workspace/CK plus/CK+48/anger/S011_004_000000...    0.0
# ..                                                 ...    ...
# 976  /workspace/CK plus/CK+48/surprise/S137_001_000...    5.0
# 977  /workspace/CK plus/CK+48/surprise/S137_001_000...    5.0
# 978  /workspace/CK plus/CK+48/surprise/S138_004_000...    5.0
# 979  /workspace/CK plus/CK+48/surprise/S138_004_000...    5.0
# 980  /workspace/CK plus/CK+48/surprise/S138_004_000...    5.0
#
# [981 rows x 2 columns]

# %%
# "Unnamed: 0"와 "path" 열 제거
df = df.drop(columns=["Unnamed: 0", "path"])

# "new_path" 열을 DataFrame 앞쪽으로 이동
df = df[["new_path", "label"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Untitled-1.ipynb Cell 7 line <cell line: 2>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=0'>1</a> # "Unnamed: 0"와 "path" 열 제거
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=1'>2</a> df = df.drop(columns=["Unnamed: 0", "path"])
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=3'>4</a> # "new_path" 열을 DataFrame 앞쪽으로 이동
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W6sdW50aXRsZWQ%3D?line=4'>5</a> df = df[["new_path", "label"]]
#
# File /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
#    4802     self,
#    (...)
#    4809     errors: str = "raise",
#    4810 ):
#    4811     """
#    4812     Drop specified labels from rows or columns.
#    4813
#    (...)
#    4946             weight  1.0     0.8
#    4947     """
# -> 4948     return super().drop(
#    4949         labels=labels,
#    4950         axis=axis,
#    4951         index=index,
#    4952         columns=columns,
#    4953         level=level,
#    4954         inplace=inplace,
#    4955         errors=errors,
#    4956     )
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:4279, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4277 for axis, labels in axes.items():
#    4278     if labels is not None:
# -> 4279         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4281 if inplace:
#    4282     self._update_inplace(obj)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:4323, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4321         new_axis = axis.drop(labels, level=level, errors=errors)
#    4322     else:
# -> 4323         new_axis = axis.drop(labels, errors=errors)
#    4324     indexer = axis.get_indexer(new_axis)
#    4326 # Case for non-unique axis
#    4327 else:
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0', 'path'] not found in axis"

# %%
df = df.rename(columns={"new_path": "path"})

df
# Out:
#                                                   path  label
# 0    /workspace/CK plus/CK+48/anger/S010_004_000000...    0.0
# 1    /workspace/CK plus/CK+48/anger/S010_004_000000...    0.0
# 2    /workspace/CK plus/CK+48/anger/S010_004_000000...    0.0
# 3    /workspace/CK plus/CK+48/anger/S011_004_000000...    0.0
# 4    /workspace/CK plus/CK+48/anger/S011_004_000000...    0.0
# ..                                                 ...    ...
# 976  /workspace/CK plus/CK+48/surprise/S137_001_000...    5.0
# 977  /workspace/CK plus/CK+48/surprise/S137_001_000...    5.0
# 978  /workspace/CK plus/CK+48/surprise/S138_004_000...    5.0
# 979  /workspace/CK plus/CK+48/surprise/S138_004_000...    5.0
# 980  /workspace/CK plus/CK+48/surprise/S138_004_000...    5.0
#
# [981 rows x 2 columns]

# %%
df.to_csv("mapping_CK_annotation.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/Affectnet/path_rename.ipynb Cell 10 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f68625f616666656374227d/workspace/Affectnet/path_rename.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> df["path"]
#
# NameError: name 'df' is not defined
